# %%
import os

# %%
rule_output = []
logical_rule = "("  #Else it is arithmetic rule
negated = "~"

def findLogicalRules(rules):
    rules = rules[1:-1] #Getting rid of the first and last parenthesis
    rules = rules.strip()
    groundAtoms = rules.split(" | ")
    
    for atoms in groundAtoms:
        if atoms[0] == negated:
            
    
    


with open('satisfaction.txt', 'r') as data:
    for line in data:
        line = line.strip()
        data_split = line.split("\t")
        rules = data_split[2]
        
        if rules[0] == logical_rule:
            findLogicalRules(rules)
# Out:
# ["~( LIVED('0', '1') )", "~( LIVED('10', '1') )", "KNOWS('10', '0')"]
# ["~( LIVED('0', '1') )", "~( LIVED('13', '1') )", "KNOWS('13', '0')"]
# ["~( LIVED('0', '1') )", "~( LIVED('2', '1') )", "KNOWS('2', '0')"]
# ["~( LIVED('0', '1') )", "~( LIVED('1', '1') )", "KNOWS('1', '0')"]
# ["~( LIVED('0', '1') )", "~( LIVED('14', '1') )", "KNOWS('14', '0')"]
# ["~( LIVED('0', '2') )", "~( LIVED('1', '2') )", "KNOWS('1', '0')"]
# ["~( LIVED('0', '2') )", "~( LIVED('14', '2') )", "KNOWS('14', '0')"]
# ["~( LIVED('0', '3') )", "~( LIVED('5', '3') )", "KNOWS('5', '0')"]
# ["~( LIVED('0', '3') )", "~( LIVED('12', '3') )", "KNOWS('12', '0')"]
# ["~( LIVED('0', '3') )", "~( LIVED('18', '3') )", "KNOWS('18', '0')"]
# ["~( LIVED('0', '4') )", "~( LIVED('1', '4') )", "KNOWS('1', '0')"]
# ["~( LIVED('0', '4') )", "~( LIVED('10', '4') )", "KNOWS('10', '0')"]
# ["~( LIVED('0', '4') )", "~( LIVED('5', '4') )", "KNOWS('5', '0')"]
# ["~( LIVED('0', '4') )", "~( LIVED('14', '4') )", "KNOWS('14', '0')"]
# ["~( LIVED('0', '4') )", "~( LIVED('13', '4') )", "KNOWS('13', '0')"]
# ["~( LIVED('0', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '0')"]
# ["~( LIVED('1', '0') )", "~( LIVED('4', '0') )", "KNOWS('4', '1')"]
# ["~( LIVED('1', '0') )", "~( LIVED('13', '0') )", "KNOWS('13', '1')"]
# ["~( LIVED('1', '0') )", "~( LIVED('14', '0') )", "KNOWS('14', '1')"]
# ["~( LIVED('0', '2') )", "~( LIVED('12', '2') )", "KNOWS('12', '0')"]
# ["~( LIVED('0', '2') )", "~( LIVED('18', '2') )", "KNOWS('18', '0')"]
# ["~( LIVED('1', '1') )", "~( LIVED('0', '1') )", "KNOWS('0', '1')"]
# ["~( LIVED('1', '1') )", "~( LIVED('4', '1') )", "KNOWS('4', '1')"]
# ["~( LIVED('1', '1') )", "~( LIVED('10', '1') )", "KNOWS('10', '1')"]
# ["~( LIVED('1', '1') )", "~( LIVED('9', '1') )", "KNOWS('9', '1')"]
# ["~( LIVED('1', '1') )", "~( LIVED('14', '1') )", "KNOWS('14', '1')"]
# ["~( LIVED('1', '1') )", "~( LIVED('13', '1') )", "KNOWS('13', '1')"]
# ["~( LIVED('1', '2') )", "~( LIVED('0', '2') )", "KNOWS('0', '1')"]
# ["~( LIVED('1', '1') )", "~( LIVED('24', '1') )", "KNOWS('24', '1')"]
# ["~( LIVED('1', '2') )", "~( LIVED('4', '2') )", "KNOWS('4', '1')"]
# ["~( LIVED('1', '2') )", "~( LIVED('9', '2') )", "KNOWS('9', '1')"]
# ["~( LIVED('1', '2') )", "~( LIVED('12', '2') )", "KNOWS('12', '1')"]
# ["~( LIVED('1', '2') )", "~( LIVED('14', '2') )", "KNOWS('14', '1')"]
# ["~( LIVED('1', '2') )", "~( LIVED('23', '2') )", "KNOWS('23', '1')"]
# ["~( LIVED('1', '4') )", "~( LIVED('0', '4') )", "KNOWS('0', '1')"]
# ["~( LIVED('1', '4') )", "~( LIVED('5', '4') )", "KNOWS('5', '1')"]
# ["~( LIVED('1', '4') )", "~( LIVED('9', '4') )", "KNOWS('9', '1')"]
# ["~( LIVED('1', '4') )", "~( LIVED('10', '4') )", "KNOWS('10', '1')"]
# ["~( LIVED('1', '4') )", "~( LIVED('13', '4') )", "KNOWS('13', '1')"]
# ["~( LIVED('1', '4') )", "~( LIVED('14', '4') )", "KNOWS('14', '1')"]
# ["~( LIVED('1', '4') )", "~( LIVED('24', '4') )", "KNOWS('24', '1')"]
# ["~( LIVED('2', '1') )", "~( LIVED('4', '1') )", "KNOWS('4', '2')"]
# ["~( LIVED('2', '1') )", "~( LIVED('13', '1') )", "KNOWS('13', '2')"]
# ["~( LIVED('2', '1') )", "~( LIVED('14', '1') )", "KNOWS('14', '2')"]
# ["~( LIVED('2', '1') )", "~( LIVED('19', '1') )", "KNOWS('19', '2')"]
# ["~( LIVED('2', '1') )", "~( LIVED('20', '1') )", "KNOWS('20', '2')"]
# ["~( LIVED('3', '0') )", "~( LIVED('7', '0') )", "KNOWS('7', '3')"]
# ["~( LIVED('2', '1') )", "~( LIVED('24', '1') )", "KNOWS('24', '2')"]
# ["~( LIVED('3', '0') )", "~( LIVED('14', '0') )", "KNOWS('14', '3')"]
# ["~( LIVED('3', '0') )", "~( LIVED('18', '0') )", "KNOWS('18', '3')"]
# ["~( LIVED('4', '0') )", "~( LIVED('3', '0') )", "KNOWS('3', '4')"]
# ["~( LIVED('4', '0') )", "~( LIVED('13', '0') )", "KNOWS('13', '4')"]
# ["~( LIVED('4', '0') )", "~( LIVED('20', '0') )", "KNOWS('20', '4')"]
# ["~( LIVED('4', '1') )", "~( LIVED('0', '1') )", "KNOWS('0', '4')"]
# ["~( LIVED('4', '1') )", "~( LIVED('10', '1') )", "KNOWS('10', '4')"]
# ["~( LIVED('4', '1') )", "~( LIVED('13', '1') )", "KNOWS('13', '4')"]
# ["~( LIVED('4', '1') )", "~( LIVED('20', '1') )", "KNOWS('20', '4')"]
# ["~( LIVED('4', '2') )", "~( LIVED('0', '2') )", "KNOWS('0', '4')"]
# ["~( LIVED('4', '3') )", "~( LIVED('0', '3') )", "KNOWS('0', '4')"]
# ["~( LIVED('4', '3') )", "~( LIVED('17', '3') )", "KNOWS('17', '4')"]
# ["~( LIVED('5', '3') )", "~( LIVED('0', '3') )", "KNOWS('0', '5')"]
# ["~( LIVED('5', '3') )", "~( LIVED('12', '3') )", "KNOWS('12', '5')"]
# ["~( LIVED('5', '4') )", "~( LIVED('0', '4') )", "KNOWS('0', '5')"]
# ["~( LIVED('6', '1') )", "~( LIVED('1', '1') )", "KNOWS('1', '6')"]
# ["~( LIVED('6', '1') )", "~( LIVED('13', '1') )", "KNOWS('13', '6')"]
# ["~( LIVED('6', '1') )", "~( LIVED('14', '1') )", "KNOWS('14', '6')"]
# ["~( LIVED('6', '1') )", "~( LIVED('16', '1') )", "KNOWS('16', '6')"]
# ["~( LIVED('6', '2') )", "~( LIVED('1', '2') )", "KNOWS('1', '6')"]
# ["~( LIVED('6', '2') )", "~( LIVED('11', '2') )", "KNOWS('11', '6')"]
# ["~( LIVED('6', '2') )", "~( LIVED('14', '2') )", "KNOWS('14', '6')"]
# ["~( LIVED('6', '2') )", "~( LIVED('18', '2') )", "KNOWS('18', '6')"]
# ["~( LIVED('6', '4') )", "~( LIVED('1', '4') )", "KNOWS('1', '6')"]
# ["~( LIVED('6', '4') )", "~( LIVED('11', '4') )", "KNOWS('11', '6')"]
# ["~( LIVED('6', '4') )", "~( LIVED('13', '4') )", "KNOWS('13', '6')"]
# ["~( LIVED('6', '4') )", "~( LIVED('14', '4') )", "KNOWS('14', '6')"]
# ["~( LIVED('6', '4') )", "~( LIVED('15', '4') )", "KNOWS('15', '6')"]
# ["~( LIVED('6', '4') )", "~( LIVED('16', '4') )", "KNOWS('16', '6')"]
# ["~( LIVED('6', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '6')"]
# ["~( LIVED('7', '0') )", "~( LIVED('4', '0') )", "KNOWS('4', '7')"]
# ["~( LIVED('7', '3') )", "~( LIVED('0', '3') )", "KNOWS('0', '7')"]
# ["~( LIVED('7', '3') )", "~( LIVED('4', '3') )", "KNOWS('4', '7')"]
# ["~( LIVED('7', '3') )", "~( LIVED('24', '3') )", "KNOWS('24', '7')"]
# ["~( LIVED('8', '0') )", "~( LIVED('4', '0') )", "KNOWS('4', '8')"]
# ["~( LIVED('8', '0') )", "~( LIVED('7', '0') )", "KNOWS('7', '8')"]
# ["~( LIVED('8', '0') )", "~( LIVED('13', '0') )", "KNOWS('13', '8')"]
# ["~( LIVED('8', '0') )", "~( LIVED('14', '0') )", "KNOWS('14', '8')"]
# ["~( LIVED('8', '0') )", "~( LIVED('16', '0') )", "KNOWS('16', '8')"]
# ["~( LIVED('8', '0') )", "~( LIVED('18', '0') )", "KNOWS('18', '8')"]
# ["~( LIVED('8', '0') )", "~( LIVED('20', '0') )", "KNOWS('20', '8')"]
# ["~( LIVED('8', '1') )", "~( LIVED('4', '1') )", "KNOWS('4', '8')"]
# ["~( LIVED('8', '1') )", "~( LIVED('6', '1') )", "KNOWS('6', '8')"]
# ["~( LIVED('8', '1') )", "~( LIVED('10', '1') )", "KNOWS('10', '8')"]
# ["~( LIVED('8', '1') )", "~( LIVED('13', '1') )", "KNOWS('13', '8')"]
# ["~( LIVED('8', '1') )", "~( LIVED('14', '1') )", "KNOWS('14', '8')"]
# ["~( LIVED('8', '1') )", "~( LIVED('16', '1') )", "KNOWS('16', '8')"]
# ["~( LIVED('8', '1') )", "~( LIVED('20', '1') )", "KNOWS('20', '8')"]
# ["~( LIVED('8', '1') )", "~( LIVED('22', '1') )", "KNOWS('22', '8')"]
# ["~( LIVED('7', '3') )", "~( LIVED('12', '3') )", "KNOWS('12', '7')"]
# ["~( LIVED('8', '2') )", "~( LIVED('4', '2') )", "KNOWS('4', '8')"]
# ["~( LIVED('8', '2') )", "~( LIVED('6', '2') )", "KNOWS('6', '8')"]
# ["~( LIVED('8', '2') )", "~( LIVED('14', '2') )", "KNOWS('14', '8')"]
# ["~( LIVED('8', '2') )", "~( LIVED('18', '2') )", "KNOWS('18', '8')"]
# ["~( LIVED('8', '4') )", "~( LIVED('6', '4') )", "KNOWS('6', '8')"]
# ["~( LIVED('8', '4') )", "~( LIVED('10', '4') )", "KNOWS('10', '8')"]
# ["~( LIVED('8', '4') )", "~( LIVED('14', '4') )", "KNOWS('14', '8')"]
# ["~( LIVED('8', '4') )", "~( LIVED('13', '4') )", "KNOWS('13', '8')"]
# ["~( LIVED('8', '4') )", "~( LIVED('16', '4') )", "KNOWS('16', '8')"]
# ["~( LIVED('8', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '8')"]
# ["~( LIVED('8', '4') )", "~( LIVED('22', '4') )", "KNOWS('22', '8')"]
# ["~( LIVED('9', '1') )", "~( LIVED('13', '1') )", "KNOWS('13', '9')"]
# ["~( LIVED('9', '1') )", "~( LIVED('14', '1') )", "KNOWS('14', '9')"]
# ["~( LIVED('9', '1') )", "~( LIVED('16', '1') )", "KNOWS('16', '9')"]
# ["~( LIVED('9', '1') )", "~( LIVED('22', '1') )", "KNOWS('22', '9')"]
# ["~( LIVED('9', '2') )", "~( LIVED('14', '2') )", "KNOWS('14', '9')"]
# ["~( LIVED('9', '2') )", "~( LIVED('18', '2') )", "KNOWS('18', '9')"]
# ["~( LIVED('9', '2') )", "~( LIVED('23', '2') )", "KNOWS('23', '9')"]
# ["~( LIVED('9', '3') )", "~( LIVED('16', '3') )", "KNOWS('16', '9')"]
# ["~( LIVED('9', '3') )", "~( LIVED('22', '3') )", "KNOWS('22', '9')"]
# ["~( LIVED('9', '3') )", "~( LIVED('18', '3') )", "KNOWS('18', '9')"]
# ["~( LIVED('9', '4') )", "~( LIVED('14', '4') )", "KNOWS('14', '9')"]
# ["~( LIVED('9', '4') )", "~( LIVED('13', '4') )", "KNOWS('13', '9')"]
# ["~( LIVED('9', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '9')"]
# ["~( LIVED('9', '4') )", "~( LIVED('16', '4') )", "KNOWS('16', '9')"]
# ["~( LIVED('9', '4') )", "~( LIVED('22', '4') )", "KNOWS('22', '9')"]
# ["~( LIVED('10', '1') )", "~( LIVED('8', '1') )", "KNOWS('8', '10')"]
# ["~( LIVED('10', '1') )", "~( LIVED('2', '1') )", "KNOWS('2', '10')"]
# ["~( LIVED('8', '0') )", "~( LIVED('3', '0') )", "KNOWS('3', '8')"]
# ["~( LIVED('10', '4') )", "~( LIVED('15', '4') )", "KNOWS('15', '10')"]
# ["~( LIVED('11', '2') )", "~( LIVED('1', '2') )", "KNOWS('1', '11')"]
# ["~( LIVED('11', '2') )", "~( LIVED('0', '2') )", "KNOWS('0', '11')"]
# ["~( LIVED('11', '2') )", "~( LIVED('4', '2') )", "KNOWS('4', '11')"]
# ["~( LIVED('10', '4') )", "~( LIVED('8', '4') )", "KNOWS('8', '10')"]
# ["~( LIVED('11', '2') )", "~( LIVED('14', '2') )", "KNOWS('14', '11')"]
# ["~( LIVED('11', '2') )", "~( LIVED('19', '2') )", "KNOWS('19', '11')"]
# ["~( LIVED('11', '3') )", "~( LIVED('0', '3') )", "KNOWS('0', '11')"]
# ["~( LIVED('11', '3') )", "~( LIVED('4', '3') )", "KNOWS('4', '11')"]
# ["~( LIVED('11', '3') )", "~( LIVED('5', '3') )", "KNOWS('5', '11')"]
# ["~( LIVED('11', '3') )", "~( LIVED('22', '3') )", "KNOWS('22', '11')"]
# ["~( LIVED('11', '4') )", "~( LIVED('1', '4') )", "KNOWS('1', '11')"]
# ["~( LIVED('11', '4') )", "~( LIVED('5', '4') )", "KNOWS('5', '11')"]
# ["~( LIVED('11', '4') )", "~( LIVED('0', '4') )", "KNOWS('0', '11')"]
# ["~( LIVED('11', '4') )", "~( LIVED('15', '4') )", "KNOWS('15', '11')"]
# ["~( LIVED('11', '4') )", "~( LIVED('22', '4') )", "KNOWS('22', '11')"]
# ["~( LIVED('12', '2') )", "~( LIVED('1', '2') )", "KNOWS('1', '12')"]
# ["~( LIVED('12', '2') )", "~( LIVED('6', '2') )", "KNOWS('6', '12')"]
# ["~( LIVED('11', '4') )", "~( LIVED('14', '4') )", "KNOWS('14', '11')"]
# ["~( LIVED('13', '0') )", "~( LIVED('1', '0') )", "KNOWS('1', '13')"]
# ["~( LIVED('13', '0') )", "~( LIVED('7', '0') )", "KNOWS('7', '13')"]
# ["~( LIVED('13', '0') )", "~( LIVED('16', '0') )", "KNOWS('16', '13')"]
# ["~( LIVED('13', '0') )", "~( LIVED('8', '0') )", "KNOWS('8', '13')"]
# ["~( LIVED('13', '0') )", "~( LIVED('18', '0') )", "KNOWS('18', '13')"]
# ["~( LIVED('13', '1') )", "~( LIVED('1', '1') )", "KNOWS('1', '13')"]
# ["~( LIVED('13', '1') )", "~( LIVED('0', '1') )", "KNOWS('0', '13')"]
# ["~( LIVED('13', '1') )", "~( LIVED('9', '1') )", "KNOWS('9', '13')"]
# ["~( LIVED('13', '1') )", "~( LIVED('8', '1') )", "KNOWS('8', '13')"]
# ["~( LIVED('13', '1') )", "~( LIVED('10', '1') )", "KNOWS('10', '13')"]
# ["~( LIVED('13', '1') )", "~( LIVED('16', '1') )", "KNOWS('16', '13')"]
# ["~( LIVED('13', '4') )", "~( LIVED('0', '4') )", "KNOWS('0', '13')"]
# ["~( LIVED('13', '4') )", "~( LIVED('5', '4') )", "KNOWS('5', '13')"]
# ["~( LIVED('13', '4') )", "~( LIVED('1', '4') )", "KNOWS('1', '13')"]
# ["~( LIVED('13', '4') )", "~( LIVED('8', '4') )", "KNOWS('8', '13')"]
# ["~( LIVED('13', '4') )", "~( LIVED('9', '4') )", "KNOWS('9', '13')"]
# ["~( LIVED('13', '4') )", "~( LIVED('10', '4') )", "KNOWS('10', '13')"]
# ["~( LIVED('13', '4') )", "~( LIVED('16', '4') )", "KNOWS('16', '13')"]
# ["~( LIVED('13', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '13')"]
# ["~( LIVED('14', '0') )", "~( LIVED('4', '0') )", "KNOWS('4', '14')"]
# ["~( LIVED('14', '0') )", "~( LIVED('21', '0') )", "KNOWS('21', '14')"]
# ["~( LIVED('14', '0') )", "~( LIVED('18', '0') )", "KNOWS('18', '14')"]
# ["~( LIVED('14', '1') )", "~( LIVED('2', '1') )", "KNOWS('2', '14')"]
# ["~( LIVED('14', '1') )", "~( LIVED('4', '1') )", "KNOWS('4', '14')"]
# ["~( LIVED('14', '1') )", "~( LIVED('22', '1') )", "KNOWS('22', '14')"]
# ["~( LIVED('14', '2') )", "~( LIVED('4', '2') )", "KNOWS('4', '14')"]
# ["~( LIVED('14', '2') )", "~( LIVED('18', '2') )", "KNOWS('18', '14')"]
# ["~( LIVED('14', '2') )", "~( LIVED('21', '2') )", "KNOWS('21', '14')"]
# ["~( LIVED('14', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '14')"]
# ["~( LIVED('14', '4') )", "~( LIVED('21', '4') )", "KNOWS('21', '14')"]
# ["~( LIVED('14', '4') )", "~( LIVED('22', '4') )", "KNOWS('22', '14')"]
# ["~( LIVED('15', '4') )", "~( LIVED('1', '4') )", "KNOWS('1', '15')"]
# ["~( LIVED('15', '4') )", "~( LIVED('11', '4') )", "KNOWS('11', '15')"]
# ["~( LIVED('15', '4') )", "~( LIVED('14', '4') )", "KNOWS('14', '15')"]
# ["~( LIVED('15', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '15')"]
# ["~( LIVED('15', '4') )", "~( LIVED('22', '4') )", "KNOWS('22', '15')"]
# ["~( LIVED('15', '4') )", "~( LIVED('21', '4') )", "KNOWS('21', '15')"]
# ["~( LIVED('16', '0') )", "~( LIVED('1', '0') )", "KNOWS('1', '16')"]
# ["~( LIVED('16', '0') )", "~( LIVED('4', '0') )", "KNOWS('4', '16')"]
# ["~( LIVED('16', '0') )", "~( LIVED('18', '0') )", "KNOWS('18', '16')"]
# ["~( LIVED('16', '0') )", "~( LIVED('13', '0') )", "KNOWS('13', '16')"]
# ["~( LIVED('16', '0') )", "~( LIVED('14', '0') )", "KNOWS('14', '16')"]
# ["~( LIVED('16', '1') )", "~( LIVED('0', '1') )", "KNOWS('0', '16')"]
# ["~( LIVED('16', '1') )", "~( LIVED('4', '1') )", "KNOWS('4', '16')"]
# ["~( LIVED('16', '1') )", "~( LIVED('1', '1') )", "KNOWS('1', '16')"]
# ["~( LIVED('16', '1') )", "~( LIVED('6', '1') )", "KNOWS('6', '16')"]
# ["~( LIVED('16', '1') )", "~( LIVED('9', '1') )", "KNOWS('9', '16')"]
# ["~( LIVED('16', '1') )", "~( LIVED('10', '1') )", "KNOWS('10', '16')"]
# ["~( LIVED('16', '1') )", "~( LIVED('13', '1') )", "KNOWS('13', '16')"]
# ["~( LIVED('16', '1') )", "~( LIVED('14', '1') )", "KNOWS('14', '16')"]
# ["~( LIVED('16', '1') )", "~( LIVED('22', '1') )", "KNOWS('22', '16')"]
# ["~( LIVED('16', '3') )", "~( LIVED('4', '3') )", "KNOWS('4', '16')"]
# ["~( LIVED('16', '3') )", "~( LIVED('0', '3') )", "KNOWS('0', '16')"]
# ["~( LIVED('16', '3') )", "~( LIVED('9', '3') )", "KNOWS('9', '16')"]
# ["~( LIVED('16', '3') )", "~( LIVED('18', '3') )", "KNOWS('18', '16')"]
# ["~( LIVED('16', '3') )", "~( LIVED('22', '3') )", "KNOWS('22', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('0', '4') )", "KNOWS('0', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('1', '4') )", "KNOWS('1', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('6', '4') )", "KNOWS('6', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('9', '4') )", "KNOWS('9', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('10', '4') )", "KNOWS('10', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('13', '4') )", "KNOWS('13', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('14', '4') )", "KNOWS('14', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('15', '4') )", "KNOWS('15', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '16')"]
# ["~( LIVED('16', '4') )", "~( LIVED('22', '4') )", "KNOWS('22', '16')"]
# ["~( LIVED('17', '3') )", "~( LIVED('9', '3') )", "KNOWS('9', '17')"]
# ["~( LIVED('17', '3') )", "~( LIVED('11', '3') )", "KNOWS('11', '17')"]
# ["~( LIVED('17', '3') )", "~( LIVED('16', '3') )", "KNOWS('16', '17')"]
# ["~( LIVED('17', '3') )", "~( LIVED('22', '3') )", "KNOWS('22', '17')"]
# ["~( LIVED('18', '0') )", "~( LIVED('4', '0') )", "KNOWS('4', '18')"]
# ["~( LIVED('18', '0') )", "~( LIVED('21', '0') )", "KNOWS('21', '18')"]
# ["~( LIVED('18', '2') )", "~( LIVED('4', '2') )", "KNOWS('4', '18')"]
# ["~( LIVED('18', '2') )", "~( LIVED('9', '2') )", "KNOWS('9', '18')"]
# ["~( LIVED('18', '2') )", "~( LIVED('6', '2') )", "KNOWS('6', '18')"]
# ["~( LIVED('18', '2') )", "~( LIVED('19', '2') )", "KNOWS('19', '18')"]
# ["~( LIVED('18', '2') )", "~( LIVED('21', '2') )", "KNOWS('21', '18')"]
# ["~( LIVED('18', '3') )", "~( LIVED('5', '3') )", "KNOWS('5', '18')"]
# ["~( LIVED('18', '3') )", "~( LIVED('4', '3') )", "KNOWS('4', '18')"]
# ["~( LIVED('18', '3') )", "~( LIVED('9', '3') )", "KNOWS('9', '18')"]
# ["~( LIVED('18', '3') )", "~( LIVED('17', '3') )", "KNOWS('17', '18')"]
# ["~( LIVED('18', '3') )", "~( LIVED('24', '3') )", "KNOWS('24', '18')"]
# ["~( LIVED('18', '4') )", "~( LIVED('5', '4') )", "KNOWS('5', '18')"]
# ["~( LIVED('18', '4') )", "~( LIVED('9', '4') )", "KNOWS('9', '18')"]
# ["~( LIVED('18', '4') )", "~( LIVED('6', '4') )", "KNOWS('6', '18')"]
# ["~( LIVED('18', '4') )", "~( LIVED('15', '4') )", "KNOWS('15', '18')"]
# ["~( LIVED('18', '4') )", "~( LIVED('21', '4') )", "KNOWS('21', '18')"]
# ["~( LIVED('19', '1') )", "~( LIVED('4', '1') )", "KNOWS('4', '19')"]
# ["~( LIVED('18', '4') )", "~( LIVED('24', '4') )", "KNOWS('24', '18')"]
# ["~( LIVED('19', '1') )", "~( LIVED('8', '1') )", "KNOWS('8', '19')"]
# ["~( LIVED('19', '1') )", "~( LIVED('9', '1') )", "KNOWS('9', '19')"]
# ["~( LIVED('19', '1') )", "~( LIVED('20', '1') )", "KNOWS('20', '19')"]
# ["~( LIVED('19', '2') )", "~( LIVED('9', '2') )", "KNOWS('9', '19')"]
# ["~( LIVED('19', '2') )", "~( LIVED('8', '2') )", "KNOWS('8', '19')"]
# ["~( LIVED('19', '2') )", "~( LIVED('11', '2') )", "KNOWS('11', '19')"]
# ["~( LIVED('20', '0') )", "~( LIVED('1', '0') )", "KNOWS('1', '20')"]
# ["~( LIVED('20', '0') )", "~( LIVED('4', '0') )", "KNOWS('4', '20')"]
# ["~( LIVED('20', '0') )", "~( LIVED('8', '0') )", "KNOWS('8', '20')"]
# ["~( LIVED('20', '0') )", "~( LIVED('7', '0') )", "KNOWS('7', '20')"]
# ["~( LIVED('20', '0') )", "~( LIVED('16', '0') )", "KNOWS('16', '20')"]
# ["~( LIVED('20', '0') )", "~( LIVED('18', '0') )", "KNOWS('18', '20')"]
# ["~( LIVED('20', '1') )", "~( LIVED('1', '1') )", "KNOWS('1', '20')"]
# ["~( LIVED('20', '1') )", "~( LIVED('4', '1') )", "KNOWS('4', '20')"]
# ["~( LIVED('20', '1') )", "~( LIVED('8', '1') )", "KNOWS('8', '20')"]
# ["~( LIVED('20', '1') )", "~( LIVED('9', '1') )", "KNOWS('9', '20')"]
# ["~( LIVED('20', '1') )", "~( LIVED('16', '1') )", "KNOWS('16', '20')"]
# ["~( LIVED('20', '1') )", "~( LIVED('19', '1') )", "KNOWS('19', '20')"]
# ["~( LIVED('21', '0') )", "~( LIVED('1', '0') )", "KNOWS('1', '21')"]
# ["~( LIVED('21', '2') )", "~( LIVED('1', '2') )", "KNOWS('1', '21')"]
# ["~( LIVED('21', '0') )", "~( LIVED('18', '0') )", "KNOWS('18', '21')"]
# ["~( LIVED('21', '2') )", "~( LIVED('6', '2') )", "KNOWS('6', '21')"]
# ["~( LIVED('21', '2') )", "~( LIVED('0', '2') )", "KNOWS('0', '21')"]
# ["~( LIVED('19', '2') )", "~( LIVED('4', '2') )", "KNOWS('4', '19')"]
# ["~( LIVED('21', '2') )", "~( LIVED('18', '2') )", "KNOWS('18', '21')"]
# ["~( LIVED('21', '2') )", "~( LIVED('23', '2') )", "KNOWS('23', '21')"]
# ["~( LIVED('21', '4') )", "~( LIVED('1', '4') )", "KNOWS('1', '21')"]
# ["~( LIVED('21', '4') )", "~( LIVED('0', '4') )", "KNOWS('0', '21')"]
# ["~( LIVED('21', '4') )", "~( LIVED('6', '4') )", "KNOWS('6', '21')"]
# ["~( LIVED('21', '4') )", "~( LIVED('9', '4') )", "KNOWS('9', '21')"]
# ["~( LIVED('21', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '21')"]
# ["~( LIVED('21', '4') )", "~( LIVED('22', '4') )", "KNOWS('22', '21')"]
# ["~( LIVED('21', '4') )", "~( LIVED('24', '4') )", "KNOWS('24', '21')"]
# ["~( LIVED('21', '2') )", "~( LIVED('9', '2') )", "KNOWS('9', '21')"]
# ["~( LIVED('22', '1') )", "~( LIVED('4', '1') )", "KNOWS('4', '22')"]
# ["~( LIVED('22', '1') )", "~( LIVED('9', '1') )", "KNOWS('9', '22')"]
# ["~( LIVED('22', '1') )", "~( LIVED('13', '1') )", "KNOWS('13', '22')"]
# ["~( LIVED('22', '1') )", "~( LIVED('19', '1') )", "KNOWS('19', '22')"]
# ["~( LIVED('22', '1') )", "~( LIVED('24', '1') )", "KNOWS('24', '22')"]
# ["~( LIVED('22', '3') )", "~( LIVED('4', '3') )", "KNOWS('4', '22')"]
# ["~( LIVED('22', '3') )", "~( LIVED('5', '3') )", "KNOWS('5', '22')"]
# ["~( LIVED('22', '3') )", "~( LIVED('7', '3') )", "KNOWS('7', '22')"]
# ["~( LIVED('22', '3') )", "~( LIVED('9', '3') )", "KNOWS('9', '22')"]
# ["~( LIVED('22', '3') )", "~( LIVED('17', '3') )", "KNOWS('17', '22')"]
# ["~( LIVED('22', '3') )", "~( LIVED('18', '3') )", "KNOWS('18', '22')"]
# ["~( LIVED('22', '3') )", "~( LIVED('24', '3') )", "KNOWS('24', '22')"]
# ["~( LIVED('22', '4') )", "~( LIVED('5', '4') )", "KNOWS('5', '22')"]
# ["~( LIVED('22', '4') )", "~( LIVED('9', '4') )", "KNOWS('9', '22')"]
# ["~( LIVED('22', '4') )", "~( LIVED('13', '4') )", "KNOWS('13', '22')"]
# ["~( LIVED('22', '4') )", "~( LIVED('18', '4') )", "KNOWS('18', '22')"]
# ["~( LIVED('22', '4') )", "~( LIVED('24', '4') )", "KNOWS('24', '22')"]
# ["~( LIVED('23', '2') )", "~( LIVED('0', '2') )", "KNOWS('0', '23')"]
# ["~( LIVED('23', '2') )", "~( LIVED('9', '2') )", "KNOWS('9', '23')"]
# ["~( LIVED('23', '2') )", "~( LIVED('12', '2') )", "KNOWS('12', '23')"]
# ["~( LIVED('23', '2') )", "~( LIVED('14', '2') )", "KNOWS('14', '23')"]
# ["~( LIVED('23', '2') )", "~( LIVED('21', '2') )", "KNOWS('21', '23')"]
# ["~( LIVED('24', '1') )", "~( LIVED('6', '1') )", "KNOWS('6', '24')"]
# ["~( LIVED('24', '1') )", "~( LIVED('8', '1') )", "KNOWS('8', '24')"]
# ["~( LIVED('24', '1') )", "~( LIVED('14', '1') )", "KNOWS('14', '24')"]
# ["~( LIVED('24', '1') )", "~( LIVED('19', '1') )", "KNOWS('19', '24')"]
# ["~( LIVED('24', '3') )", "~( LIVED('17', '3') )", "KNOWS('17', '24')"]
# ["~( LIVED('24', '4') )", "~( LIVED('6', '4') )", "KNOWS('6', '24')"]
# ["~( LIVED('24', '4') )", "~( LIVED('8', '4') )", "KNOWS('8', '24')"]
# ["~( LIVED('24', '4') )", "~( LIVED('14', '4') )", "KNOWS('14', '24')"]
# ["~( LIVED('24', '4') )", "~( LIVED('15', '4') )", "KNOWS('15', '24')"]
# ["~( LOCALLIKES('0', '0') )", "~( LOCALLIKES('1', '0') )", "KNOWS('0', '1')"]
# ["~( LOCALLIKES('0', '0') )", "~( LOCALLIKES('11', '0') )", "KNOWS('0', '11')"]
# ["~( LOCALLIKES('0', '0') )", "~( LOCALLIKES('5', '0') )", "KNOWS('0', '5')"]
# ["~( LOCALLIKES('0', '0') )", "~( LOCALLIKES('7', '0') )", "KNOWS('0', '7')"]
# ["~( LOCALLIKES('0', '0') )", "~( LOCALLIKES('13', '0') )", "KNOWS('0', '13')"]
# ["~( LOCALLIKES('0', '0') )", "~( LOCALLIKES('16', '0') )", "KNOWS('0', '16')"]
# ["~( LOCALLIKES('0', '0') )", "~( LOCALLIKES('4', '0') )", "KNOWS('0', '4')"]
# ["~( LOCALLIKES('0', '0') )", "~( LOCALLIKES('21', '0') )", "KNOWS('0', '21')"]
# ["~( LOCALLIKES('0', '0') )", "~( LOCALLIKES('23', '0') )", "KNOWS('0', '23')"]
# ["~( LOCALLIKES('0', '1') )", "~( LOCALLIKES('1', '1') )", "KNOWS('0', '1')"]
# ["~( LOCALLIKES('0', '1') )", "~( LOCALLIKES('4', '1') )", "KNOWS('0', '4')"]
# ["~( LOCALLIKES('0', '1') )", "~( LOCALLIKES('7', '1') )", "KNOWS('0', '7')"]
# ["~( LOCALLIKES('0', '1') )", "~( LOCALLIKES('5', '1') )", "KNOWS('0', '5')"]
# ["~( LOCALLIKES('0', '1') )", "~( LOCALLIKES('11', '1') )", "KNOWS('0', '11')"]
# ["~( LOCALLIKES('0', '1') )", "~( LOCALLIKES('13', '1') )", "KNOWS('0', '13')"]
# ["~( LOCALLIKES('0', '1') )", "~( LOCALLIKES('16', '1') )", "KNOWS('0', '16')"]
# ["~( LOCALLIKES('0', '1') )", "~( LOCALLIKES('21', '1') )", "KNOWS('0', '21')"]
# ["~( LOCALLIKES('0', '1') )", "~( LOCALLIKES('23', '1') )", "KNOWS('0', '23')"]
# ["~( LOCALLIKES('0', '2') )", "~( LOCALLIKES('4', '2') )", "KNOWS('0', '4')"]
# ["~( LOCALLIKES('0', '2') )", "~( LOCALLIKES('1', '2') )", "KNOWS('0', '1')"]
# ["~( LOCALLIKES('0', '2') )", "~( LOCALLIKES('5', '2') )", "KNOWS('0', '5')"]
# ["~( LOCALLIKES('0', '2') )", "~( LOCALLIKES('7', '2') )", "KNOWS('0', '7')"]
# ["~( LOCALLIKES('0', '2') )", "~( LOCALLIKES('11', '2') )", "KNOWS('0', '11')"]
# ["~( LOCALLIKES('0', '2') )", "~( LOCALLIKES('13', '2') )", "KNOWS('0', '13')"]
# ["~( LOCALLIKES('0', '2') )", "~( LOCALLIKES('16', '2') )", "KNOWS('0', '16')"]
# ["~( LOCALLIKES('0', '2') )", "~( LOCALLIKES('21', '2') )", "KNOWS('0', '21')"]
# ["~( LOCALLIKES('0', '2') )", "~( LOCALLIKES('23', '2') )", "KNOWS('0', '23')"]
# ["~( LOCALLIKES('0', '3') )", "~( LOCALLIKES('1', '3') )", "KNOWS('0', '1')"]
# ["~( LOCALLIKES('0', '3') )", "~( LOCALLIKES('5', '3') )", "KNOWS('0', '5')"]
# ["~( LOCALLIKES('0', '3') )", "~( LOCALLIKES('4', '3') )", "KNOWS('0', '4')"]
# ["~( LOCALLIKES('0', '3') )", "~( LOCALLIKES('7', '3') )", "KNOWS('0', '7')"]
# ["~( LOCALLIKES('0', '3') )", "~( LOCALLIKES('11', '3') )", "KNOWS('0', '11')"]
# ["~( LOCALLIKES('0', '3') )", "~( LOCALLIKES('13', '3') )", "KNOWS('0', '13')"]
# ["~( LOCALLIKES('0', '3') )", "~( LOCALLIKES('16', '3') )", "KNOWS('0', '16')"]
# ["~( LOCALLIKES('0', '3') )", "~( LOCALLIKES('21', '3') )", "KNOWS('0', '21')"]
# ["~( LOCALLIKES('0', '3') )", "~( LOCALLIKES('23', '3') )", "KNOWS('0', '23')"]
# ["~( LOCALLIKES('0', '4') )", "~( LOCALLIKES('1', '4') )", "KNOWS('0', '1')"]
# ["~( LOCALLIKES('0', '4') )", "~( LOCALLIKES('4', '4') )", "KNOWS('0', '4')"]
# ["~( LOCALLIKES('0', '4') )", "~( LOCALLIKES('5', '4') )", "KNOWS('0', '5')"]
# ["~( LOCALLIKES('0', '4') )", "~( LOCALLIKES('7', '4') )", "KNOWS('0', '7')"]
# ["~( LOCALLIKES('0', '4') )", "~( LOCALLIKES('11', '4') )", "KNOWS('0', '11')"]
# ["~( LOCALLIKES('0', '4') )", "~( LOCALLIKES('13', '4') )", "KNOWS('0', '13')"]
# ["~( LOCALLIKES('0', '4') )", "~( LOCALLIKES('16', '4') )", "KNOWS('0', '16')"]
# ["~( LOCALLIKES('0', '4') )", "~( LOCALLIKES('21', '4') )", "KNOWS('0', '21')"]
# ["~( LOCALLIKES('0', '4') )", "~( LOCALLIKES('23', '4') )", "KNOWS('0', '23')"]
# ["~( LOCALLIKES('1', '0') )", "~( LOCALLIKES('0', '0') )", "KNOWS('1', '0')"]
# ["~( LOCALLIKES('1', '0') )", "~( LOCALLIKES('6', '0') )", "KNOWS('1', '6')"]
# ["~( LOCALLIKES('1', '0') )", "~( LOCALLIKES('11', '0') )", "KNOWS('1', '11')"]
# ["~( LOCALLIKES('1', '0') )", "~( LOCALLIKES('12', '0') )", "KNOWS('1', '12')"]
# ["~( LOCALLIKES('1', '0') )", "~( LOCALLIKES('13', '0') )", "KNOWS('1', '13')"]
# ["~( LOCALLIKES('1', '0') )", "~( LOCALLIKES('15', '0') )", "KNOWS('1', '15')"]
# ["~( LOCALLIKES('1', '0') )", "~( LOCALLIKES('16', '0') )", "KNOWS('1', '16')"]
# ["~( LOCALLIKES('1', '0') )", "~( LOCALLIKES('20', '0') )", "KNOWS('1', '20')"]
# ["~( LOCALLIKES('1', '0') )", "~( LOCALLIKES('21', '0') )", "KNOWS('1', '21')"]
# ["~( LOCALLIKES('1', '1') )", "~( LOCALLIKES('0', '1') )", "KNOWS('1', '0')"]
# ["~( LOCALLIKES('1', '1') )", "~( LOCALLIKES('6', '1') )", "KNOWS('1', '6')"]
# ["~( LOCALLIKES('1', '1') )", "~( LOCALLIKES('12', '1') )", "KNOWS('1', '12')"]
# ["~( LOCALLIKES('1', '1') )", "~( LOCALLIKES('11', '1') )", "KNOWS('1', '11')"]
# ["~( LOCALLIKES('1', '1') )", "~( LOCALLIKES('13', '1') )", "KNOWS('1', '13')"]
# ["~( LOCALLIKES('1', '1') )", "~( LOCALLIKES('15', '1') )", "KNOWS('1', '15')"]
# ["~( LOCALLIKES('1', '1') )", "~( LOCALLIKES('16', '1') )", "KNOWS('1', '16')"]
# ["~( LOCALLIKES('1', '1') )", "~( LOCALLIKES('21', '1') )", "KNOWS('1', '21')"]
# ["~( LOCALLIKES('1', '1') )", "~( LOCALLIKES('20', '1') )", "KNOWS('1', '20')"]
# ["~( LOCALLIKES('1', '2') )", "~( LOCALLIKES('0', '2') )", "KNOWS('1', '0')"]
# ["~( LOCALLIKES('1', '2') )", "~( LOCALLIKES('6', '2') )", "KNOWS('1', '6')"]
# ["~( LOCALLIKES('1', '2') )", "~( LOCALLIKES('11', '2') )", "KNOWS('1', '11')"]
# ["~( LOCALLIKES('1', '2') )", "~( LOCALLIKES('12', '2') )", "KNOWS('1', '12')"]
# ["~( LOCALLIKES('1', '2') )", "~( LOCALLIKES('16', '2') )", "KNOWS('1', '16')"]
# ["~( LOCALLIKES('1', '3') )", "~( LOCALLIKES('0', '3') )", "KNOWS('1', '0')"]
# ["~( LOCALLIKES('1', '3') )", "~( LOCALLIKES('6', '3') )", "KNOWS('1', '6')"]
# ["~( LOCALLIKES('1', '2') )", "~( LOCALLIKES('21', '2') )", "KNOWS('1', '21')"]
# ["~( LOCALLIKES('1', '3') )", "~( LOCALLIKES('11', '3') )", "KNOWS('1', '11')"]
# ["~( LOCALLIKES('1', '3') )", "~( LOCALLIKES('12', '3') )", "KNOWS('1', '12')"]
# ["~( LOCALLIKES('1', '2') )", "~( LOCALLIKES('20', '2') )", "KNOWS('1', '20')"]
# ["~( LOCALLIKES('1', '2') )", "~( LOCALLIKES('13', '2') )", "KNOWS('1', '13')"]
# ["~( LOCALLIKES('1', '3') )", "~( LOCALLIKES('13', '3') )", "KNOWS('1', '13')"]
# ["~( LOCALLIKES('1', '2') )", "~( LOCALLIKES('15', '2') )", "KNOWS('1', '15')"]
# ["~( LOCALLIKES('1', '3') )", "~( LOCALLIKES('15', '3') )", "KNOWS('1', '15')"]
# ["~( LOCALLIKES('1', '3') )", "~( LOCALLIKES('16', '3') )", "KNOWS('1', '16')"]
# ["~( LOCALLIKES('1', '3') )", "~( LOCALLIKES('20', '3') )", "KNOWS('1', '20')"]
# ["~( LOCALLIKES('1', '3') )", "~( LOCALLIKES('21', '3') )", "KNOWS('1', '21')"]
# ["~( LOCALLIKES('1', '4') )", "~( LOCALLIKES('0', '4') )", "KNOWS('1', '0')"]
# ["~( LOCALLIKES('1', '4') )", "~( LOCALLIKES('6', '4') )", "KNOWS('1', '6')"]
# ["~( LOCALLIKES('1', '4') )", "~( LOCALLIKES('11', '4') )", "KNOWS('1', '11')"]
# ["~( LOCALLIKES('1', '4') )", "~( LOCALLIKES('12', '4') )", "KNOWS('1', '12')"]
# ["~( LOCALLIKES('1', '4') )", "~( LOCALLIKES('13', '4') )", "KNOWS('1', '13')"]
# ["~( LOCALLIKES('1', '4') )", "~( LOCALLIKES('15', '4') )", "KNOWS('1', '15')"]
# ["~( LOCALLIKES('1', '4') )", "~( LOCALLIKES('16', '4') )", "KNOWS('1', '16')"]
# ["~( LOCALLIKES('1', '4') )", "~( LOCALLIKES('20', '4') )", "KNOWS('1', '20')"]
# ["~( LOCALLIKES('1', '4') )", "~( LOCALLIKES('21', '4') )", "KNOWS('1', '21')"]
# ["~( LOCALLIKES('2', '0') )", "~( LOCALLIKES('0', '0') )", "KNOWS('2', '0')"]
# ["~( LOCALLIKES('2', '0') )", "~( LOCALLIKES('10', '0') )", "KNOWS('2', '10')"]
# ["~( LOCALLIKES('2', '0') )", "~( LOCALLIKES('14', '0') )", "KNOWS('2', '14')"]
# ["~( LOCALLIKES('2', '0') )", "~( LOCALLIKES('15', '0') )", "KNOWS('2', '15')"]
# ["~( LOCALLIKES('2', '0') )", "~( LOCALLIKES('17', '0') )", "KNOWS('2', '17')"]
# ["~( LOCALLIKES('2', '0') )", "~( LOCALLIKES('18', '0') )", "KNOWS('2', '18')"]
# ["~( LOCALLIKES('2', '0') )", "~( LOCALLIKES('23', '0') )", "KNOWS('2', '23')"]
# ["~( LOCALLIKES('2', '1') )", "~( LOCALLIKES('0', '1') )", "KNOWS('2', '0')"]
# ["~( LOCALLIKES('2', '1') )", "~( LOCALLIKES('10', '1') )", "KNOWS('2', '10')"]
# ["~( LOCALLIKES('2', '1') )", "~( LOCALLIKES('15', '1') )", "KNOWS('2', '15')"]
# ["~( LOCALLIKES('2', '1') )", "~( LOCALLIKES('14', '1') )", "KNOWS('2', '14')"]
# ["~( LOCALLIKES('2', '1') )", "~( LOCALLIKES('18', '1') )", "KNOWS('2', '18')"]
# ["~( LOCALLIKES('2', '1') )", "~( LOCALLIKES('17', '1') )", "KNOWS('2', '17')"]
# ["~( LOCALLIKES('2', '1') )", "~( LOCALLIKES('23', '1') )", "KNOWS('2', '23')"]
# ["~( LOCALLIKES('2', '2') )", "~( LOCALLIKES('0', '2') )", "KNOWS('2', '0')"]
# ["~( LOCALLIKES('2', '2') )", "~( LOCALLIKES('10', '2') )", "KNOWS('2', '10')"]
# ["~( LOCALLIKES('2', '2') )", "~( LOCALLIKES('15', '2') )", "KNOWS('2', '15')"]
# ["~( LOCALLIKES('2', '2') )", "~( LOCALLIKES('14', '2') )", "KNOWS('2', '14')"]
# ["~( LOCALLIKES('2', '2') )", "~( LOCALLIKES('17', '2') )", "KNOWS('2', '17')"]
# ["~( LOCALLIKES('2', '2') )", "~( LOCALLIKES('18', '2') )", "KNOWS('2', '18')"]
# ["~( LOCALLIKES('2', '2') )", "~( LOCALLIKES('23', '2') )", "KNOWS('2', '23')"]
# ["~( LOCALLIKES('2', '3') )", "~( LOCALLIKES('0', '3') )", "KNOWS('2', '0')"]
# ["~( LOCALLIKES('2', '3') )", "~( LOCALLIKES('10', '3') )", "KNOWS('2', '10')"]
# ["~( LOCALLIKES('2', '3') )", "~( LOCALLIKES('14', '3') )", "KNOWS('2', '14')"]
# ["~( LOCALLIKES('2', '3') )", "~( LOCALLIKES('15', '3') )", "KNOWS('2', '15')"]
# ["~( LOCALLIKES('2', '3') )", "~( LOCALLIKES('17', '3') )", "KNOWS('2', '17')"]
# ["~( LOCALLIKES('2', '3') )", "~( LOCALLIKES('18', '3') )", "KNOWS('2', '18')"]
# ["~( LOCALLIKES('2', '3') )", "~( LOCALLIKES('23', '3') )", "KNOWS('2', '23')"]
# ["~( LOCALLIKES('2', '4') )", "~( LOCALLIKES('0', '4') )", "KNOWS('2', '0')"]
# ["~( LOCALLIKES('2', '4') )", "~( LOCALLIKES('10', '4') )", "KNOWS('2', '10')"]
# ["~( LOCALLIKES('2', '4') )", "~( LOCALLIKES('14', '4') )", "KNOWS('2', '14')"]
# ["~( LOCALLIKES('2', '4') )", "~( LOCALLIKES('15', '4') )", "KNOWS('2', '15')"]
# ["~( LOCALLIKES('2', '4') )", "~( LOCALLIKES('17', '4') )", "KNOWS('2', '17')"]
# ["~( LOCALLIKES('2', '4') )", "~( LOCALLIKES('18', '4') )", "KNOWS('2', '18')"]
# ["~( LOCALLIKES('2', '4') )", "~( LOCALLIKES('23', '4') )", "KNOWS('2', '23')"]
# ["~( LOCALLIKES('3', '0') )", "~( LOCALLIKES('0', '0') )", "KNOWS('3', '0')"]
# ["~( LOCALLIKES('3', '0') )", "~( LOCALLIKES('5', '0') )", "KNOWS('3', '5')"]
# ["~( LOCALLIKES('3', '0') )", "~( LOCALLIKES('4', '0') )", "KNOWS('3', '4')"]
# ["~( LOCALLIKES('3', '0') )", "~( LOCALLIKES('6', '0') )", "KNOWS('3', '6')"]
# ["~( LOCALLIKES('3', '0') )", "~( LOCALLIKES('11', '0') )", "KNOWS('3', '11')"]
# ["~( LOCALLIKES('3', '0') )", "~( LOCALLIKES('10', '0') )", "KNOWS('3', '10')"]
# ["~( LOCALLIKES('3', '0') )", "~( LOCALLIKES('8', '0') )", "KNOWS('3', '8')"]
# ["~( LOCALLIKES('3', '0') )", "~( LOCALLIKES('17', '0') )", "KNOWS('3', '17')"]
# ["~( LOCALLIKES('3', '1') )", "~( LOCALLIKES('0', '1') )", "KNOWS('3', '0')"]
# ["~( LOCALLIKES('3', '1') )", "~( LOCALLIKES('4', '1') )", "KNOWS('3', '4')"]
# ["~( LOCALLIKES('3', '1') )", "~( LOCALLIKES('6', '1') )", "KNOWS('3', '6')"]
# ["~( LOCALLIKES('3', '1') )", "~( LOCALLIKES('5', '1') )", "KNOWS('3', '5')"]
# ["~( LOCALLIKES('3', '1') )", "~( LOCALLIKES('8', '1') )", "KNOWS('3', '8')"]
# ["~( LOCALLIKES('3', '1') )", "~( LOCALLIKES('10', '1') )", "KNOWS('3', '10')"]
# ["~( LOCALLIKES('3', '1') )", "~( LOCALLIKES('11', '1') )", "KNOWS('3', '11')"]
# ["~( LOCALLIKES('3', '1') )", "~( LOCALLIKES('17', '1') )", "KNOWS('3', '17')"]
# ["~( LOCALLIKES('3', '2') )", "~( LOCALLIKES('0', '2') )", "KNOWS('3', '0')"]
# ["~( LOCALLIKES('3', '2') )", "~( LOCALLIKES('4', '2') )", "KNOWS('3', '4')"]
# ["~( LOCALLIKES('3', '2') )", "~( LOCALLIKES('5', '2') )", "KNOWS('3', '5')"]
# ["~( LOCALLIKES('3', '2') )", "~( LOCALLIKES('6', '2') )", "KNOWS('3', '6')"]
# ["~( LOCALLIKES('3', '2') )", "~( LOCALLIKES('8', '2') )", "KNOWS('3', '8')"]
# ["~( LOCALLIKES('3', '2') )", "~( LOCALLIKES('10', '2') )", "KNOWS('3', '10')"]
# ["~( LOCALLIKES('3', '2') )", "~( LOCALLIKES('11', '2') )", "KNOWS('3', '11')"]
# ["~( LOCALLIKES('3', '2') )", "~( LOCALLIKES('17', '2') )", "KNOWS('3', '17')"]
# ["~( LOCALLIKES('3', '3') )", "~( LOCALLIKES('0', '3') )", "KNOWS('3', '0')"]
# ["~( LOCALLIKES('3', '3') )", "~( LOCALLIKES('4', '3') )", "KNOWS('3', '4')"]
# ["~( LOCALLIKES('3', '3') )", "~( LOCALLIKES('5', '3') )", "KNOWS('3', '5')"]
# ["~( LOCALLIKES('3', '3') )", "~( LOCALLIKES('6', '3') )", "KNOWS('3', '6')"]
# ["~( LOCALLIKES('3', '3') )", "~( LOCALLIKES('8', '3') )", "KNOWS('3', '8')"]
# ["~( LOCALLIKES('3', '3') )", "~( LOCALLIKES('10', '3') )", "KNOWS('3', '10')"]
# ["~( LOCALLIKES('3', '3') )", "~( LOCALLIKES('11', '3') )", "KNOWS('3', '11')"]
# ["~( LOCALLIKES('3', '3') )", "~( LOCALLIKES('17', '3') )", "KNOWS('3', '17')"]
# ["~( LOCALLIKES('3', '4') )", "~( LOCALLIKES('0', '4') )", "KNOWS('3', '0')"]
# ["~( LOCALLIKES('3', '4') )", "~( LOCALLIKES('4', '4') )", "KNOWS('3', '4')"]
# ["~( LOCALLIKES('3', '4') )", "~( LOCALLIKES('5', '4') )", "KNOWS('3', '5')"]
# ["~( LOCALLIKES('3', '4') )", "~( LOCALLIKES('6', '4') )", "KNOWS('3', '6')"]
# ["~( LOCALLIKES('3', '4') )", "~( LOCALLIKES('8', '4') )", "KNOWS('3', '8')"]
# ["~( LOCALLIKES('3', '4') )", "~( LOCALLIKES('10', '4') )", "KNOWS('3', '10')"]
# ["~( LOCALLIKES('3', '4') )", "~( LOCALLIKES('11', '4') )", "KNOWS('3', '11')"]
# ["~( LOCALLIKES('3', '4') )", "~( LOCALLIKES('17', '4') )", "KNOWS('3', '17')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('1', '0') )", "KNOWS('4', '1')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('2', '0') )", "KNOWS('4', '2')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('7', '0') )", "KNOWS('4', '7')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('8', '0') )", "KNOWS('4', '8')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('11', '0') )", "KNOWS('4', '11')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('14', '0') )", "KNOWS('4', '14')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('15', '0') )", "KNOWS('4', '15')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('16', '0') )", "KNOWS('4', '16')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('18', '0') )", "KNOWS('4', '18')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('19', '0') )", "KNOWS('4', '19')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('20', '0') )", "KNOWS('4', '20')"]
# ["~( LOCALLIKES('4', '0') )", "~( LOCALLIKES('22', '0') )", "KNOWS('4', '22')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('1', '1') )", "KNOWS('4', '1')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('2', '1') )", "KNOWS('4', '2')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('7', '1') )", "KNOWS('4', '7')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('8', '1') )", "KNOWS('4', '8')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('11', '1') )", "KNOWS('4', '11')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('14', '1') )", "KNOWS('4', '14')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('15', '1') )", "KNOWS('4', '15')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('16', '1') )", "KNOWS('4', '16')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('18', '1') )", "KNOWS('4', '18')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('19', '1') )", "KNOWS('4', '19')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('20', '1') )", "KNOWS('4', '20')"]
# ["~( LOCALLIKES('4', '1') )", "~( LOCALLIKES('22', '1') )", "KNOWS('4', '22')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('1', '2') )", "KNOWS('4', '1')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('2', '2') )", "KNOWS('4', '2')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('7', '2') )", "KNOWS('4', '7')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('8', '2') )", "KNOWS('4', '8')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('11', '2') )", "KNOWS('4', '11')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('14', '2') )", "KNOWS('4', '14')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('15', '2') )", "KNOWS('4', '15')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('16', '2') )", "KNOWS('4', '16')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('18', '2') )", "KNOWS('4', '18')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('19', '2') )", "KNOWS('4', '19')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('22', '2') )", "KNOWS('4', '22')"]
# ["~( LOCALLIKES('4', '2') )", "~( LOCALLIKES('20', '2') )", "KNOWS('4', '20')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('1', '3') )", "KNOWS('4', '1')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('2', '3') )", "KNOWS('4', '2')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('7', '3') )", "KNOWS('4', '7')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('8', '3') )", "KNOWS('4', '8')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('11', '3') )", "KNOWS('4', '11')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('14', '3') )", "KNOWS('4', '14')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('16', '3') )", "KNOWS('4', '16')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('15', '3') )", "KNOWS('4', '15')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('19', '3') )", "KNOWS('4', '19')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('18', '3') )", "KNOWS('4', '18')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('20', '3') )", "KNOWS('4', '20')"]
# ["~( LOCALLIKES('4', '3') )", "~( LOCALLIKES('22', '3') )", "KNOWS('4', '22')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('1', '4') )", "KNOWS('4', '1')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('2', '4') )", "KNOWS('4', '2')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('7', '4') )", "KNOWS('4', '7')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('8', '4') )", "KNOWS('4', '8')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('11', '4') )", "KNOWS('4', '11')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('14', '4') )", "KNOWS('4', '14')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('15', '4') )", "KNOWS('4', '15')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('16', '4') )", "KNOWS('4', '16')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('18', '4') )", "KNOWS('4', '18')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('19', '4') )", "KNOWS('4', '19')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('20', '4') )", "KNOWS('4', '20')"]
# ["~( LOCALLIKES('4', '4') )", "~( LOCALLIKES('22', '4') )", "KNOWS('4', '22')"]
# ["~( LOCALLIKES('5', '0') )", "~( LOCALLIKES('0', '0') )", "KNOWS('5', '0')"]
# ["~( LOCALLIKES('5', '0') )", "~( LOCALLIKES('1', '0') )", "KNOWS('5', '1')"]
# ["~( LOCALLIKES('5', '0') )", "~( LOCALLIKES('11', '0') )", "KNOWS('5', '11')"]
# ["~( LOCALLIKES('5', '0') )", "~( LOCALLIKES('13', '0') )", "KNOWS('5', '13')"]
# ["~( LOCALLIKES('5', '0') )", "~( LOCALLIKES('18', '0') )", "KNOWS('5', '18')"]
# ["~( LOCALLIKES('5', '0') )", "~( LOCALLIKES('19', '0') )", "KNOWS('5', '19')"]
# ["~( LOCALLIKES('5', '0') )", "~( LOCALLIKES('20', '0') )", "KNOWS('5', '20')"]
# ["~( LOCALLIKES('5', '0') )", "~( LOCALLIKES('22', '0') )", "KNOWS('5', '22')"]
# ["~( LOCALLIKES('5', '1') )", "~( LOCALLIKES('0', '1') )", "KNOWS('5', '0')"]
# ["~( LOCALLIKES('5', '1') )", "~( LOCALLIKES('1', '1') )", "KNOWS('5', '1')"]
# ["~( LOCALLIKES('5', '1') )", "~( LOCALLIKES('11', '1') )", "KNOWS('5', '11')"]
# ["~( LOCALLIKES('5', '1') )", "~( LOCALLIKES('13', '1') )", "KNOWS('5', '13')"]
# ["~( LOCALLIKES('5', '1') )", "~( LOCALLIKES('18', '1') )", "KNOWS('5', '18')"]
# ["~( LOCALLIKES('5', '1') )", "~( LOCALLIKES('19', '1') )", "KNOWS('5', '19')"]
# ["~( LOCALLIKES('5', '1') )", "~( LOCALLIKES('20', '1') )", "KNOWS('5', '20')"]
# ["~( LOCALLIKES('5', '1') )", "~( LOCALLIKES('22', '1') )", "KNOWS('5', '22')"]
# ["~( LOCALLIKES('5', '2') )", "~( LOCALLIKES('0', '2') )", "KNOWS('5', '0')"]
# ["~( LOCALLIKES('5', '2') )", "~( LOCALLIKES('1', '2') )", "KNOWS('5', '1')"]
# ["~( LOCALLIKES('5', '2') )", "~( LOCALLIKES('11', '2') )", "KNOWS('5', '11')"]
# ["~( LOCALLIKES('5', '2') )", "~( LOCALLIKES('13', '2') )", "KNOWS('5', '13')"]
# ["~( LOCALLIKES('5', '2') )", "~( LOCALLIKES('18', '2') )", "KNOWS('5', '18')"]
# ["~( LOCALLIKES('5', '2') )", "~( LOCALLIKES('19', '2') )", "KNOWS('5', '19')"]
# ["~( LOCALLIKES('5', '2') )", "~( LOCALLIKES('20', '2') )", "KNOWS('5', '20')"]
# ["~( LOCALLIKES('5', '2') )", "~( LOCALLIKES('22', '2') )", "KNOWS('5', '22')"]
# ["~( LOCALLIKES('5', '3') )", "~( LOCALLIKES('0', '3') )", "KNOWS('5', '0')"]
# ["~( LOCALLIKES('5', '3') )", "~( LOCALLIKES('1', '3') )", "KNOWS('5', '1')"]
# ["~( LOCALLIKES('5', '3') )", "~( LOCALLIKES('11', '3') )", "KNOWS('5', '11')"]
# ["~( LOCALLIKES('5', '3') )", "~( LOCALLIKES('13', '3') )", "KNOWS('5', '13')"]
# ["~( LOCALLIKES('5', '3') )", "~( LOCALLIKES('18', '3') )", "KNOWS('5', '18')"]
# ["~( LOCALLIKES('5', '3') )", "~( LOCALLIKES('19', '3') )", "KNOWS('5', '19')"]
# ["~( LOCALLIKES('5', '3') )", "~( LOCALLIKES('20', '3') )", "KNOWS('5', '20')"]
# ["~( LOCALLIKES('5', '3') )", "~( LOCALLIKES('22', '3') )", "KNOWS('5', '22')"]
# ["~( LOCALLIKES('5', '4') )", "~( LOCALLIKES('0', '4') )", "KNOWS('5', '0')"]
# ["~( LOCALLIKES('5', '4') )", "~( LOCALLIKES('1', '4') )", "KNOWS('5', '1')"]
# ["~( LOCALLIKES('5', '4') )", "~( LOCALLIKES('11', '4') )", "KNOWS('5', '11')"]
# ["~( LOCALLIKES('5', '4') )", "~( LOCALLIKES('13', '4') )", "KNOWS('5', '13')"]
# ["~( LOCALLIKES('5', '4') )", "~( LOCALLIKES('18', '4') )", "KNOWS('5', '18')"]
# ["~( LOCALLIKES('5', '4') )", "~( LOCALLIKES('19', '4') )", "KNOWS('5', '19')"]
# ["~( LOCALLIKES('5', '4') )", "~( LOCALLIKES('20', '4') )", "KNOWS('5', '20')"]
# ["~( LOCALLIKES('5', '4') )", "~( LOCALLIKES('22', '4') )", "KNOWS('5', '22')"]
# ["~( LOCALLIKES('6', '0') )", "~( LOCALLIKES('3', '0') )", "KNOWS('6', '3')"]
# ["~( LOCALLIKES('6', '0') )", "~( LOCALLIKES('8', '0') )", "KNOWS('6', '8')"]
# ["~( LOCALLIKES('6', '0') )", "~( LOCALLIKES('12', '0') )", "KNOWS('6', '12')"]
# ["~( LOCALLIKES('6', '0') )", "~( LOCALLIKES('16', '0') )", "KNOWS('6', '16')"]
# ["~( LOCALLIKES('6', '0') )", "~( LOCALLIKES('18', '0') )", "KNOWS('6', '18')"]
# ["~( LOCALLIKES('6', '0') )", "~( LOCALLIKES('21', '0') )", "KNOWS('6', '21')"]
# ["~( LOCALLIKES('6', '0') )", "~( LOCALLIKES('24', '0') )", "KNOWS('6', '24')"]
# ["~( LOCALLIKES('6', '1') )", "~( LOCALLIKES('3', '1') )", "KNOWS('6', '3')"]
# ["~( LOCALLIKES('6', '1') )", "~( LOCALLIKES('8', '1') )", "KNOWS('6', '8')"]
# ["~( LOCALLIKES('6', '1') )", "~( LOCALLIKES('12', '1') )", "KNOWS('6', '12')"]
# ["~( LOCALLIKES('6', '1') )", "~( LOCALLIKES('18', '1') )", "KNOWS('6', '18')"]
# ["~( LOCALLIKES('6', '1') )", "~( LOCALLIKES('16', '1') )", "KNOWS('6', '16')"]
# ["~( LOCALLIKES('6', '1') )", "~( LOCALLIKES('21', '1') )", "KNOWS('6', '21')"]
# ["~( LOCALLIKES('6', '1') )", "~( LOCALLIKES('24', '1') )", "KNOWS('6', '24')"]
# ["~( LOCALLIKES('6', '2') )", "~( LOCALLIKES('3', '2') )", "KNOWS('6', '3')"]
# ["~( LOCALLIKES('6', '2') )", "~( LOCALLIKES('8', '2') )", "KNOWS('6', '8')"]
# ["~( LOCALLIKES('6', '2') )", "~( LOCALLIKES('12', '2') )", "KNOWS('6', '12')"]
# ["~( LOCALLIKES('6', '2') )", "~( LOCALLIKES('16', '2') )", "KNOWS('6', '16')"]
# ["~( LOCALLIKES('6', '2') )", "~( LOCALLIKES('18', '2') )", "KNOWS('6', '18')"]
# ["~( LOCALLIKES('6', '2') )", "~( LOCALLIKES('21', '2') )", "KNOWS('6', '21')"]
# ["~( LOCALLIKES('6', '2') )", "~( LOCALLIKES('24', '2') )", "KNOWS('6', '24')"]
# ["~( LOCALLIKES('6', '3') )", "~( LOCALLIKES('3', '3') )", "KNOWS('6', '3')"]
# ["~( LOCALLIKES('6', '3') )", "~( LOCALLIKES('8', '3') )", "KNOWS('6', '8')"]
# ["~( LOCALLIKES('6', '3') )", "~( LOCALLIKES('12', '3') )", "KNOWS('6', '12')"]
# ["~( LOCALLIKES('6', '3') )", "~( LOCALLIKES('16', '3') )", "KNOWS('6', '16')"]
# ["~( LOCALLIKES('6', '3') )", "~( LOCALLIKES('18', '3') )", "KNOWS('6', '18')"]
# ["~( LOCALLIKES('6', '3') )", "~( LOCALLIKES('21', '3') )", "KNOWS('6', '21')"]
# ["~( LOCALLIKES('6', '3') )", "~( LOCALLIKES('24', '3') )", "KNOWS('6', '24')"]
# ["~( LOCALLIKES('6', '4') )", "~( LOCALLIKES('3', '4') )", "KNOWS('6', '3')"]
# ["~( LOCALLIKES('6', '4') )", "~( LOCALLIKES('8', '4') )", "KNOWS('6', '8')"]
# ["~( LOCALLIKES('6', '4') )", "~( LOCALLIKES('12', '4') )", "KNOWS('6', '12')"]
# ["~( LOCALLIKES('6', '4') )", "~( LOCALLIKES('16', '4') )", "KNOWS('6', '16')"]
# ["~( LOCALLIKES('6', '4') )", "~( LOCALLIKES('18', '4') )", "KNOWS('6', '18')"]
# ["~( LOCALLIKES('6', '4') )", "~( LOCALLIKES('21', '4') )", "KNOWS('6', '21')"]
# ["~( LOCALLIKES('6', '4') )", "~( LOCALLIKES('24', '4') )", "KNOWS('6', '24')"]
# ["~( LOCALLIKES('7', '0') )", "~( LOCALLIKES('3', '0') )", "KNOWS('7', '3')"]
# ["~( LOCALLIKES('7', '0') )", "~( LOCALLIKES('6', '0') )", "KNOWS('7', '6')"]
# ["~( LOCALLIKES('7', '0') )", "~( LOCALLIKES('8', '0') )", "KNOWS('7', '8')"]
# ["~( LOCALLIKES('7', '0') )", "~( LOCALLIKES('13', '0') )", "KNOWS('7', '13')"]
# ["~( LOCALLIKES('7', '0') )", "~( LOCALLIKES('15', '0') )", "KNOWS('7', '15')"]
# ["~( LOCALLIKES('7', '0') )", "~( LOCALLIKES('20', '0') )", "KNOWS('7', '20')"]
# ["~( LOCALLIKES('7', '0') )", "~( LOCALLIKES('22', '0') )", "KNOWS('7', '22')"]
# ["~( LOCALLIKES('7', '1') )", "~( LOCALLIKES('3', '1') )", "KNOWS('7', '3')"]
# ["~( LOCALLIKES('7', '1') )", "~( LOCALLIKES('6', '1') )", "KNOWS('7', '6')"]
# ["~( LOCALLIKES('7', '1') )", "~( LOCALLIKES('8', '1') )", "KNOWS('7', '8')"]
# ["~( LOCALLIKES('7', '1') )", "~( LOCALLIKES('13', '1') )", "KNOWS('7', '13')"]
# ["~( LOCALLIKES('7', '1') )", "~( LOCALLIKES('15', '1') )", "KNOWS('7', '15')"]
# ["~( LOCALLIKES('7', '1') )", "~( LOCALLIKES('20', '1') )", "KNOWS('7', '20')"]
# ["~( LOCALLIKES('7', '1') )", "~( LOCALLIKES('22', '1') )", "KNOWS('7', '22')"]
# ["~( LOCALLIKES('7', '2') )", "~( LOCALLIKES('3', '2') )", "KNOWS('7', '3')"]
# ["~( LOCALLIKES('7', '2') )", "~( LOCALLIKES('6', '2') )", "KNOWS('7', '6')"]
# ["~( LOCALLIKES('7', '2') )", "~( LOCALLIKES('8', '2') )", "KNOWS('7', '8')"]
# ["~( LOCALLIKES('7', '2') )", "~( LOCALLIKES('13', '2') )", "KNOWS('7', '13')"]
# ["~( LOCALLIKES('7', '2') )", "~( LOCALLIKES('15', '2') )", "KNOWS('7', '15')"]
# ["~( LOCALLIKES('7', '2') )", "~( LOCALLIKES('20', '2') )", "KNOWS('7', '20')"]
# ["~( LOCALLIKES('7', '2') )", "~( LOCALLIKES('22', '2') )", "KNOWS('7', '22')"]
# ["~( LOCALLIKES('7', '3') )", "~( LOCALLIKES('3', '3') )", "KNOWS('7', '3')"]
# ["~( LOCALLIKES('7', '3') )", "~( LOCALLIKES('6', '3') )", "KNOWS('7', '6')"]
# ["~( LOCALLIKES('7', '3') )", "~( LOCALLIKES('8', '3') )", "KNOWS('7', '8')"]
# ["~( LOCALLIKES('7', '3') )", "~( LOCALLIKES('13', '3') )", "KNOWS('7', '13')"]
# ["~( LOCALLIKES('7', '3') )", "~( LOCALLIKES('15', '3') )", "KNOWS('7', '15')"]
# ["~( LOCALLIKES('7', '3') )", "~( LOCALLIKES('20', '3') )", "KNOWS('7', '20')"]
# ["~( LOCALLIKES('7', '3') )", "~( LOCALLIKES('22', '3') )", "KNOWS('7', '22')"]
# ["~( LOCALLIKES('7', '4') )", "~( LOCALLIKES('3', '4') )", "KNOWS('7', '3')"]
# ["~( LOCALLIKES('7', '4') )", "~( LOCALLIKES('6', '4') )", "KNOWS('7', '6')"]
# ["~( LOCALLIKES('7', '4') )", "~( LOCALLIKES('8', '4') )", "KNOWS('7', '8')"]
# ["~( LOCALLIKES('7', '4') )", "~( LOCALLIKES('13', '4') )", "KNOWS('7', '13')"]
# ["~( LOCALLIKES('7', '4') )", "~( LOCALLIKES('15', '4') )", "KNOWS('7', '15')"]
# ["~( LOCALLIKES('7', '4') )", "~( LOCALLIKES('20', '4') )", "KNOWS('7', '20')"]
# ["~( LOCALLIKES('7', '4') )", "~( LOCALLIKES('22', '4') )", "KNOWS('7', '22')"]
# ["~( LOCALLIKES('8', '0') )", "~( LOCALLIKES('10', '0') )", "KNOWS('8', '10')"]
# ["~( LOCALLIKES('8', '0') )", "~( LOCALLIKES('13', '0') )", "KNOWS('8', '13')"]
# ["~( LOCALLIKES('8', '0') )", "~( LOCALLIKES('19', '0') )", "KNOWS('8', '19')"]
# ["~( LOCALLIKES('8', '0') )", "~( LOCALLIKES('20', '0') )", "KNOWS('8', '20')"]
# ...
# ["~( LIVED('21', '4') )", "~( KNOWS('18', '21') )", "~( LIVED('18', '3') )"]
# ["~( LIVED('22', '1') )", "~( KNOWS('18', '22') )", "~( LIVED('18', '2') )"]
# ["~( LIVED('22', '1') )", "~( KNOWS('18', '22') )", "~( LIVED('18', '3') )"]
# ["~( LIVED('22', '1') )", "~( KNOWS('18', '22') )", "~( LIVED('18', '4') )"]
# ["~( LIVED('22', '3') )", "~( KNOWS('18', '22') )", "~( LIVED('18', '2') )"]
# ["~( LIVED('22', '3') )", "~( KNOWS('18', '22') )", "~( LIVED('18', '4') )"]
# ["~( LIVED('22', '4') )", "~( KNOWS('18', '22') )", "~( LIVED('18', '2') )"]
# ["~( LIVED('22', '4') )", "~( KNOWS('18', '22') )", "~( LIVED('18', '0') )"]
# ["~( LIVED('22', '4') )", "~( KNOWS('18', '22') )", "~( LIVED('18', '3') )"]
# ["~( LIVED('2', '1') )", "~( KNOWS('19', '2') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('7', '0') )", "~( KNOWS('19', '7') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('7', '0') )", "~( KNOWS('19', '7') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('7', '3') )", "~( KNOWS('19', '7') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('7', '3') )", "~( KNOWS('19', '7') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('22', '3') )", "~( KNOWS('18', '22') )", "~( LIVED('18', '0') )"]
# ["~( LIVED('11', '3') )", "~( KNOWS('19', '11') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('11', '2') )", "~( KNOWS('19', '11') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('11', '3') )", "~( KNOWS('19', '11') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('11', '4') )", "~( KNOWS('19', '11') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('11', '4') )", "~( KNOWS('19', '11') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('15', '4') )", "~( KNOWS('19', '15') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('18', '0') )", "~( KNOWS('19', '18') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('18', '0') )", "~( KNOWS('19', '18') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('18', '3') )", "~( KNOWS('19', '18') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('18', '3') )", "~( KNOWS('19', '18') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('15', '4') )", "~( KNOWS('19', '15') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('18', '2') )", "~( KNOWS('19', '18') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('18', '4') )", "~( KNOWS('19', '18') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('8', '1') )", "~( KNOWS('18', '8') )", "~( LIVED('18', '4') )"]
# ["~( LIVED('18', '4') )", "~( KNOWS('19', '18') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('20', '0') )", "~( KNOWS('19', '20') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('20', '0') )", "~( KNOWS('19', '20') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('22', '1') )", "~( KNOWS('19', '22') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('20', '1') )", "~( KNOWS('19', '20') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('22', '3') )", "~( KNOWS('19', '22') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('22', '3') )", "~( KNOWS('19', '22') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('22', '4') )", "~( KNOWS('19', '22') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('22', '4') )", "~( KNOWS('19', '22') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('24', '1') )", "~( KNOWS('19', '24') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('24', '3') )", "~( KNOWS('19', '24') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('24', '3') )", "~( KNOWS('19', '24') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('24', '4') )", "~( KNOWS('19', '24') )", "~( LIVED('19', '1') )"]
# ["~( LIVED('24', '4') )", "~( KNOWS('19', '24') )", "~( LIVED('19', '2') )"]
# ["~( LIVED('2', '1') )", "~( KNOWS('20', '2') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('4', '0') )", "~( KNOWS('20', '4') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('4', '1') )", "~( KNOWS('20', '4') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('4', '2') )", "~( KNOWS('20', '4') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('4', '2') )", "~( KNOWS('20', '4') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('21', '2') )", "~( KNOWS('18', '21') )", "~( LIVED('18', '0') )"]
# ["~( LIVED('4', '3') )", "~( KNOWS('20', '4') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('5', '3') )", "~( KNOWS('20', '5') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('5', '4') )", "~( KNOWS('20', '5') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('5', '3') )", "~( KNOWS('20', '5') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('5', '4') )", "~( KNOWS('20', '5') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('8', '1') )", "~( KNOWS('20', '8') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('8', '2') )", "~( KNOWS('20', '8') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('8', '2') )", "~( KNOWS('20', '8') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('8', '0') )", "~( KNOWS('20', '8') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('4', '3') )", "~( KNOWS('20', '4') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('8', '4') )", "~( KNOWS('20', '8') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('8', '4') )", "~( KNOWS('20', '8') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('11', '2') )", "~( KNOWS('20', '11') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('11', '2') )", "~( KNOWS('20', '11') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('11', '3') )", "~( KNOWS('20', '11') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('11', '3') )", "~( KNOWS('20', '11') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('11', '4') )", "~( KNOWS('20', '11') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('17', '3') )", "~( KNOWS('20', '17') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('17', '3') )", "~( KNOWS('20', '17') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('11', '4') )", "~( KNOWS('20', '11') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('19', '1') )", "~( KNOWS('20', '19') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('19', '2') )", "~( KNOWS('20', '19') )", "~( LIVED('20', '0') )"]
# ["~( LIVED('14', '0') )", "~( KNOWS('21', '14') )", "~( LIVED('21', '2') )"]
# ["~( LIVED('14', '0') )", "~( KNOWS('21', '14') )", "~( LIVED('21', '4') )"]
# ["~( LIVED('19', '2') )", "~( KNOWS('20', '19') )", "~( LIVED('20', '1') )"]
# ["~( LIVED('14', '1') )", "~( KNOWS('21', '14') )", "~( LIVED('21', '0') )"]
# ["~( LIVED('14', '1') )", "~( KNOWS('21', '14') )", "~( LIVED('21', '2') )"]
# ["~( LIVED('14', '1') )", "~( KNOWS('21', '14') )", "~( LIVED('21', '4') )"]
# ["~( LIVED('14', '2') )", "~( KNOWS('21', '14') )", "~( LIVED('21', '0') )"]
# ["~( LIVED('14', '2') )", "~( KNOWS('21', '14') )", "~( LIVED('21', '4') )"]
# ["~( LIVED('14', '4') )", "~( KNOWS('21', '14') )", "~( LIVED('21', '0') )"]
# ["~( LIVED('14', '4') )", "~( KNOWS('21', '14') )", "~( LIVED('21', '2') )"]
# ["~( LIVED('15', '4') )", "~( KNOWS('21', '15') )", "~( LIVED('21', '0') )"]
# ["~( LIVED('15', '4') )", "~( KNOWS('21', '15') )", "~( LIVED('21', '2') )"]
# ["~( LIVED('18', '0') )", "~( KNOWS('21', '18') )", "~( LIVED('21', '2') )"]
# ["~( LIVED('18', '2') )", "~( KNOWS('21', '18') )", "~( LIVED('21', '0') )"]
# ["~( LIVED('18', '3') )", "~( KNOWS('21', '18') )", "~( LIVED('21', '0') )"]
# ["~( LIVED('18', '3') )", "~( KNOWS('21', '18') )", "~( LIVED('21', '2') )"]
# ["~( LIVED('18', '2') )", "~( KNOWS('21', '18') )", "~( LIVED('21', '4') )"]
# ["~( LIVED('18', '4') )", "~( KNOWS('21', '18') )", "~( LIVED('21', '0') )"]
# ["~( LIVED('18', '4') )", "~( KNOWS('21', '18') )", "~( LIVED('21', '2') )"]
# ["~( LIVED('23', '2') )", "~( KNOWS('21', '23') )", "~( LIVED('21', '4') )"]
# ["~( LIVED('8', '0') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('8', '0') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('18', '3') )", "~( KNOWS('21', '18') )", "~( LIVED('21', '4') )"]
# ["~( LIVED('8', '0') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('8', '1') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('8', '1') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('8', '2') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('8', '2') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('23', '2') )", "~( KNOWS('21', '23') )", "~( LIVED('21', '0') )"]
# ["~( LIVED('18', '0') )", "~( KNOWS('21', '18') )", "~( LIVED('21', '4') )"]
# ["~( LIVED('8', '2') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('8', '4') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('9', '1') )", "~( KNOWS('22', '9') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('8', '4') )", "~( KNOWS('22', '8') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('9', '2') )", "~( KNOWS('22', '9') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('9', '1') )", "~( KNOWS('22', '9') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('9', '2') )", "~( KNOWS('22', '9') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('9', '3') )", "~( KNOWS('22', '9') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('9', '3') )", "~( KNOWS('22', '9') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('9', '2') )", "~( KNOWS('22', '9') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('9', '4') )", "~( KNOWS('22', '9') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('11', '2') )", "~( KNOWS('22', '11') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('9', '4') )", "~( KNOWS('22', '9') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('11', '2') )", "~( KNOWS('22', '11') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('11', '2') )", "~( KNOWS('22', '11') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('11', '3') )", "~( KNOWS('22', '11') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('11', '3') )", "~( KNOWS('22', '11') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('14', '0') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('11', '4') )", "~( KNOWS('22', '11') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('11', '4') )", "~( KNOWS('22', '11') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('14', '0') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('14', '0') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('14', '1') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('14', '2') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('14', '2') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('14', '1') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('14', '4') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('14', '2') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('15', '4') )", "~( KNOWS('22', '15') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('14', '4') )", "~( KNOWS('22', '14') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('15', '4') )", "~( KNOWS('22', '15') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('16', '0') )", "~( KNOWS('22', '16') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('16', '0') )", "~( KNOWS('22', '16') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('16', '0') )", "~( KNOWS('22', '16') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('16', '1') )", "~( KNOWS('22', '16') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('16', '1') )", "~( KNOWS('22', '16') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('16', '3') )", "~( KNOWS('22', '16') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('16', '3') )", "~( KNOWS('22', '16') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('16', '4') )", "~( KNOWS('22', '16') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('16', '4') )", "~( KNOWS('22', '16') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('17', '3') )", "~( KNOWS('22', '17') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('17', '3') )", "~( KNOWS('22', '17') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('21', '0') )", "~( KNOWS('22', '21') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('21', '0') )", "~( KNOWS('22', '21') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('21', '2') )", "~( KNOWS('22', '21') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('21', '0') )", "~( KNOWS('22', '21') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('21', '2') )", "~( KNOWS('22', '21') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('21', '4') )", "~( KNOWS('22', '21') )", "~( LIVED('22', '1') )"]
# ["~( LIVED('21', '2') )", "~( KNOWS('22', '21') )", "~( LIVED('22', '4') )"]
# ["~( LIVED('21', '4') )", "~( KNOWS('22', '21') )", "~( LIVED('22', '3') )"]
# ["~( LIVED('1', '0') )", "~( KNOWS('23', '1') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('1', '1') )", "~( KNOWS('23', '1') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('1', '4') )", "~( KNOWS('23', '1') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('3', '0') )", "~( KNOWS('23', '3') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('7', '0') )", "~( KNOWS('23', '7') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('7', '3') )", "~( KNOWS('23', '7') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('9', '1') )", "~( KNOWS('23', '9') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('9', '3') )", "~( KNOWS('23', '9') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('10', '1') )", "~( KNOWS('23', '10') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('10', '4') )", "~( KNOWS('23', '10') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('21', '0') )", "~( KNOWS('23', '21') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('9', '4') )", "~( KNOWS('23', '9') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('21', '4') )", "~( KNOWS('23', '21') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('17', '3') )", "~( KNOWS('23', '17') )", "~( LIVED('23', '2') )"]
# ["~( LIVED('1', '0') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('1', '0') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('1', '1') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('1', '0') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('1', '1') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('1', '2') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('1', '2') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('1', '2') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('1', '4') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('1', '4') )", "~( KNOWS('24', '1') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('2', '1') )", "~( KNOWS('24', '2') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('7', '0') )", "~( KNOWS('24', '7') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('2', '1') )", "~( KNOWS('24', '2') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('7', '0') )", "~( KNOWS('24', '7') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('7', '0') )", "~( KNOWS('24', '7') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('7', '3') )", "~( KNOWS('24', '7') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('7', '3') )", "~( KNOWS('24', '7') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('18', '0') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('18', '0') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('18', '0') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('18', '2') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('18', '2') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('18', '2') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('18', '3') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('18', '4') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('18', '3') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('18', '4') )", "~( KNOWS('24', '18') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('21', '0') )", "~( KNOWS('24', '21') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('21', '0') )", "~( KNOWS('24', '21') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('21', '0') )", "~( KNOWS('24', '21') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('21', '2') )", "~( KNOWS('24', '21') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('21', '2') )", "~( KNOWS('24', '21') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('21', '2') )", "~( KNOWS('24', '21') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('21', '4') )", "~( KNOWS('24', '21') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('21', '4') )", "~( KNOWS('24', '21') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('22', '1') )", "~( KNOWS('24', '22') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('22', '1') )", "~( KNOWS('24', '22') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('22', '3') )", "~( KNOWS('24', '22') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('22', '3') )", "~( KNOWS('24', '22') )", "~( LIVED('24', '4') )"]
# ["~( LIVED('22', '4') )", "~( KNOWS('24', '22') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('22', '4') )", "~( KNOWS('24', '22') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('23', '2') )", "~( KNOWS('24', '23') )", "~( LIVED('24', '1') )"]
# ["~( LIVED('23', '2') )", "~( KNOWS('24', '23') )", "~( LIVED('24', '3') )"]
# ["~( LIVED('23', '2') )", "~( KNOWS('24', '23') )", "~( LIVED('24', '4') )"]
